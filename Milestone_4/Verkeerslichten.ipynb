# %%
import csv, re, requests
from rdflib import Dataset, URIRef, Literal, Namespace, RDF, RDFS, OWL, XSD
from iribaker import to_iri
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
# from geomet import wkt
# pip install git+git://github.com/geomet/geomet.git

# %%
TUTORIAL_REPOSITORY = "http://stardog.krw.d2s.labs.vu.nl/group12"

def upload_to_stardog(data):
    transaction_begin_url = TUTORIAL_REPOSITORY + "/transaction/begin"
    
    # Start the transaction, and get a transaction_id
    response = requests.post(transaction_begin_url, headers={'Accept': 'text/plain'})
    transaction_id = response.content
    
    # POST the data to the transaction
    post_url = TUTORIAL_REPOSITORY + "/" + transaction_id + "/add"
    response = requests.post(post_url, data=data, headers={'Accept': 'text/plain', 'Content-type': 'application/trig'})
    
    # Close the transaction
    transaction_close_url = TUTORIAL_REPOSITORY + "/transaction/commit/" + transaction_id
    response = requests.post(transaction_close_url)

    return str(response.status_code)

# %%
VALID_CHARS = list("ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789-")

# %%
# A namespace for our resources
data = 'http://data.krw.d2s.labs.vu.nl/group12/resource/'
DATA = Namespace(data)
# A namespace for our vocabulary items (schema information, RDFS, OWL classes and properties etc.)
vocab = 'http://data.krw.d2s.labs.vu.nl/group12/vocab/'
VOCAB = Namespace('http://data.krw.d2s.labs.vu.nl/group12/vocab/')

# The URI for our graph
graph_uri = URIRef('http://data.krw.d2s.labs.vu.nl/group12/resource/trafficlightgraph')

# We initialize a dataset, and bind our namespaces
dataset = Dataset()
dataset.bind('g12data',DATA)
dataset.bind('g12vocab',VOCAB)

# We then get a new graph object with our URI from the dataset.
graph = dataset.graph(graph_uri)

# Create namespaces for our Geo-data
GSP = Namespace('http://www.opengis.net/ont/geosparql#')
GSF = Namespace('http://www.opengis.net/ont/sf#')

# %%
myFile = open('../Milestone 1/data/VERKEERSLICHTEN.csv', 'r')
verkeerslichten = csv.reader(myFile, delimiter=',', quotechar='"')

headers = verkeerslichten.next()
headers[0] = headers[0].split('\xef\xbb\xbf')[1] if headers[0].startswith('\xef') else headers[0]

idIDX = headers.index('OBJECTNUMMER')
kpnIDX = headers.index('Kruispuntnummer')
krpIDX = headers.index('Kruispunt')
gerIDX = headers.index('Geregeld_sinds_schatting')
verIDX = headers.index('Vervallen_sinds_schatting')
regIDX = headers.index('Regeling')
srtIDX = headers.index('Soort')
kopIDX = headers.index('Koppeling')
staIDX = headers.index('Status')
webIDX = headers.index('Weblink')
cooIDX = headers.index('COORDS')
latIDX = headers.index('CENTERLAT2')
lngIDX = headers.index('CENTERLNG2')

# %%
# Load the externally defined schema into the default graph (context) of the dataset
dataset.default_context.parse('vocab.ttl', format='turtle')

# create pattern for splitting streets in Kruispunt column
splitpattern = re.compile(r' / *| - ')

# http://dbpedia.org/page/Amsterdam
for row in verkeerslichten:
    # first create the URI's
    verkeerslicht      = URIRef(to_iri(data + 'TrafficLight/' + row[idIDX]))
    verkeerslichtNaam  = Literal('Trafficlight' + row[idIDX], datatype=XSD['string'])
    kruispunt          = URIRef(to_iri(data + 'TrafficlightJunction/' + row[idIDX]))
    kruispuntNaam      = Literal('TrafficlightJunction' + row[idIDX], datatype=XSD['string'])
    kruispuntNummer    = Literal(row[kpnIDX], datatype=XSD['int'])
    if row[gerIDX].strip() != '0' and row[gerIDX].strip() != ' ':
        geregeldSinds  = Literal(row[gerIDX], datatype=XSD['gYear'])
    else:
        geregeldSinds = ''
    if row[verIDX].strip() != '0' and row[verIDX].strip() != '':
        vervallenSinds = Literal(row[verIDX], datatype=XSD['gYear'])
    else:
        vervallenSinds = ''
    status             = Literal(row[staIDX], lang='nl')
    straatURI = []
    straatNaam = []
    for el in re.split(splitpattern, row[krpIDX]):
        el = el.strip()
        temp = ''.join([c for c in el.replace(' ', '_') if c in VALID_CHARS])
        straatURI.append(URIRef(to_iri(data + temp)))
        straatNaam.append(Literal(el, lang='nl'))
    regeling           = Literal(row[regIDX], lang='nl')
    soort              = Literal(row[srtIDX], lang='nl')
    koppeling          = Literal(row[kopIDX], lang='nl')
    weblink            = URIRef(to_iri(row[webIDX])) if row[webIDX].strip() != '' else ''
    # original data uses Dutch decimal mark (comma), switch to dot
#     try:
#         newLat = float(row[latIDX].replace(',', '.'))
#     except ValueError:
#         newLat = 0.0
#     lat = Literal(newLat, datatype=XSD['float'])
#     try:
#         newLng = float(row[lngIDX].replace(',', '.'))
#     except ValueError:
#         newLng = 0.0
#     lng = Literal(newLng, datatype=XSD['float'])
    coords             = Literal(row[cooIDX], datatype=GSP.wktLiteral)
    myTLPoint          = URIRef(to_iri(data + 'TrafficLight/' + row[idIDX] + '/Point'))
    myTLJPoint         = URIRef(to_iri(data + 'TrafficLightJunction/' + row[idIDX] + '/Point'))
    
    # second create the actual triples
    graph.add((verkeerslicht, RDF.type, VOCAB['Trafficlight']))
    print verkeerslicht
    print RDF.type
    print VOCAB['Trafficlight']
    graph.add((verkeerslicht, RDFS.label, verkeerslichtNaam))
    graph.add((verkeerslicht, GSP.hasGeometry, myTLPoint))
    graph.add((verkeerslicht, VOCAB['trafficlightJunction'], kruispunt))
    if geregeldSinds != '':
        graph.add((verkeerslicht, VOCAB['geregeldSinds'], geregeldSinds))
    if vervallenSinds != '':
        graph.add((verkeerslicht, VOCAB['vervallenSinds'], vervallenSinds))
    graph.add((verkeerslicht, VOCAB['status'], status))
    graph.add((verkeerslicht, VOCAB['regeling'], regeling))
    graph.add((verkeerslicht, VOCAB['soort'], soort))
    graph.add((verkeerslicht, VOCAB['koppeling'], koppeling))
    if weblink != '':
        graph.add((verkeerslicht, VOCAB['weblink'], weblink))
#     graph.add((verkeerslicht, VOCAB['lat'], lat))
#     graph.add((verkeerslicht, VOCAB['lng'], lng))
    graph.add((kruispunt, RDF.type, VOCAB['TrafficlightJunction']))
    graph.add((kruispunt, RDFS.label, kruispuntNaam))
    graph.add((kruispunt, VOCAB['trafficlight'], verkeerslicht))
    graph.add((kruispunt, VOCAB['kruispuntnummer'], kruispuntNummer))
#     graph.add((kruispunt, VOCAB['lat'], lat))
#     graph.add((kruispunt, VOCAB['lng'], lng))
    for uri, naam in zip(straatURI, straatNaam):
        graph.add((uri, RDF.type, VOCAB['Street']))
        graph.add((uri, RDFS.label, naam))
        graph.add((kruispunt, VOCAB['street'], uri))
    graph.add((kruispunt, GSP.hasGeometry, myTLJPoint))
    graph.add((myTLPoint, RDF.type, GSF.Point))
    graph.add((myTLPoint, GSP.asWKT, coords))
    graph.add((myTLJPoint, RDF.type, GSF.Point))
    graph.add((myTLJPoint, GSP.asWKT, coords))

# close the csv file
myFile.close()

# print 'response.status_code = ' + upload_to_stardog(dataset.serialize(format='trig'))
# Out:
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/1
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/2
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/3
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/4
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/5
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/6
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/7
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/8
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/9
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/10
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/11
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/12
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/13
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/14
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/15
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/16
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/17
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/18
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/19
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/20
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/21
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/22
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/23
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/24
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/25
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/26
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/28
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/29
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/30
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/31
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/32
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/33
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/34
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/35
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/36
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/37
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/38
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/39
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/40
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/41
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/42
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/43
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/44
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/45
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/46
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/47
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/48
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/49
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/50
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/51
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/52
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/53
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/54
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/55
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/56
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/57
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/58
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/59
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/60
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/61
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/62
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/63
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/64
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/65
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/66
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/67
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/68
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/69
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/70
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/71
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/72
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/73
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/74
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/75
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/76
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/77
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/78
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/79
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/80
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/81
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/82
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/83
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/84
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/85
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/86
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/87
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/88
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/89
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/90
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/91
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/92
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/93
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/94
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/95
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/96
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/97
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/98
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/99
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/100
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/101
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/102
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/103
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/104
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/105
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/106
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/107
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/108
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/109
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/110
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/111
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/112
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/113
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/114
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/115
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/116
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/117
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/118
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/119
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/120
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/121
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/122
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/123
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/124
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/125
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/126
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/127
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/128
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/129
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/130
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/131
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/132
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/133
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/134
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/135
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/136
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/137
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/138
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/139
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/140
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/141
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/142
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/143
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/144
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/145
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/146
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/147
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/148
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/149
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/150
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/151
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/152
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/153
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/154
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/155
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/156
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/157
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/158
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/159
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/160
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/161
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/162
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/163
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/164
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/165
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/166
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/167
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/168
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/169
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/170
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/171
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/172
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/173
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/174
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/175
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/176
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/177
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/178
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/179
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/180
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/181
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/182
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/183
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/184
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/185
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/186
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/187
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/188
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/189
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/190
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/191
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/192
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/193
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/194
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/195
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/196
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/197
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/198
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/199
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/200
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/201
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/202
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/203
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/204
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/205
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/206
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/207
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/208
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/209
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/210
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/211
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/212
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/213
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/214
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/215
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/216
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/217
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/218
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/219
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/220
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/221
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/222
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/223
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/224
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/225
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/226
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/227
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/228
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/230
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/231
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/232
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/233
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/234
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/235
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/236
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/237
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/238
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/239
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/240
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/241
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/242
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/243
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/244
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/245
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/246
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/247
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/248
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/249
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/250
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/251
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/252
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/253
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/254
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/255
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/256
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/257
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/258
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/259
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/260
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/261
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/262
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/263
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/264
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/265
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/266
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/267
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/268
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/269
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/270
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/271
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/272
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/273
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/274
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/275
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/276
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/277
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/278
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/279
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/280
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/281
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/282
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/283
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# ...
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/491
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/492
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/493
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/494
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/495
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/496
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/497
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/498
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/499
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/500
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/501
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/502
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/503
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/504
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/505
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/506
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/507
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/508
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/509
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/510
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/511
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/512
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/513
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/514
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/515
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/658
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/517
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/518
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/519
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/520
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/521
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/522
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/523
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/524
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/525
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/526
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/527
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/528
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/529
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/530
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/531
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/532
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/533
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/534
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/535
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/536
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/537
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/538
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/539
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/540
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/541
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/542
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/543
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/544
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/545
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/546
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/547
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/548
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/549
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/550
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/551
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/552
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/553
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/554
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/555
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/556
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/557
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/558
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/559
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/560
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/561
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/562
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/563
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/564
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/565
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/566
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/567
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/568
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/569
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/570
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/571
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/572
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/573
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/652
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/653
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/654
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/655
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/656
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/657
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/661
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/663
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/665
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight
# http://data.krw.d2s.labs.vu.nl/group12/resource/TrafficLight/688
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://data.krw.d2s.labs.vu.nl/group12/vocab/Trafficlight

# %%
#print dataset.serialize(format='trig')

# %%
# with open('trafficlights-rdf.trig','w') as f:
#     dataset.serialize(f, format='trig')

# %%
query = """
PREFIX gr12vocab: <http://data.krw.d2s.labs.vu.nl/group12/vocab/> 

SELECT * WHERE {
  # ?x a gr12vocab:Verkeerslicht .
}LIMIT 10"""

endpoint = TUTORIAL_REPOSITORY + '/query'

sparql = SPARQLWrapper(endpoint)

sparql.setQuery(query)

sparql.setReturnFormat(JSON)
sparql.addParameter('Accept','application/sparql-results+json')
# Out:
# True

# %%
#sparql.addParameter('reasoning','false')
#response = sparql.query().convert()
#print response

# %%
#sparql.addParameter('reasoning','true')
#response = sparql.query().convert()
#print response
